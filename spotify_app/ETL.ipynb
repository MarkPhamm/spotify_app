# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\hamin\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\hamin\anaconda3\lib\site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: six>=1.15.0 in c:\users\hamin\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\hamin\anaconda3\lib\site-packages (from spotipy) (5.0.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\hamin\anaconda3\lib\site-packages (from spotipy) (2.26.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\hamin\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hamin\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hamin\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hamin\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(
    client_id="3bb988d3549f41908d0a7ab799d962e5", 
    client_secret="7a9146e9861249ebba524a14d9f3a614")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza'

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
sp.playlist_tracks(playlist_URI)

# %%
# Initialize an empty list to store all the tracks
all_tracks = []

# Initialize the offset to 0
offset = 0

# Set the limit to the maximum allowed (100 tracks per request)
limit = 100

while True:
    # Retrieve the next batch of tracks
    batch = sp.playlist_tracks(playlist_URI, offset=offset, limit=limit)

    # Add the batch of tracks to the list
    all_tracks.extend(batch['items'])

    # Check if there are more tracks to retrieve
    if len(batch['items']) < limit:
        break

    # Increment the offset for the next request
    offset += limit

# Continue with the rest of your code to process the data

# The code that follows can remain the same as in your original code
data = {
    'href': batch['href'],  # The last href from the loop
    'items': all_tracks
}
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
# data = sp.playlist_tracks(playlist_URI)

# %%
# Retrive Track Information
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#   'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#   'id': '4yP0hdKOZPNshxUOjY0cZj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#     'width': 64}],
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#    'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#    'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#    'name': 'The Weeknd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 200040,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUG11904206'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'},
#  'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#  'id': '0VjIjW4GlUZAMYd2vXMi3b',
#  'is_local': False,
#  'name': 'Blinding Lights',
#  'popularity': 90,
#  'preview_url': None,
#  'track': True,
#  'track_number': 9,
#  'type': 'track',
#  'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b'}

# %%
# Retrive Album Information
data['items'][0]['track']['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#    'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#    'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#    'name': 'The Weeknd',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#  'id': '4yP0hdKOZPNshxUOjY0cZj',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#    'width': 64}],
#  'name': 'After Hours',
#  'release_date': '2020-03-20',
#  'release_date_precision': 'day',
#  'total_tracks': 14,
#  'type': 'album',
#  'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '4yP0hdKOZPNshxUOjY0cZj'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-03-20'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 14

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = album_id = row['track']['album']['name']
    album_release_date = album_id = row['track']['album']['release_date']
    album_total_tracks = album_id = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date' :album_release_date, 'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)
print(len(album_list))
# Out:
# 772

# %%
album_list
# Out:
# [{'album_id': 14,
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': 16,
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 12,
#   'name': 'Divinely Uninspired To A Hellish Extent',
#   'release_date': '2019-05-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5658aM19fA3JVwTK6eQX70'},
#  {'album_id': 20,
#   'name': 'Welcome To The Madhouse (Deluxe)',
#   'release_date': '2021-07-16',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/1AZjTOqvw2ZogWZxnDlhEN'},
#  {'album_id': 13,
#   'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#   'release_date': '2018-12-14',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#  {'album_id': 18,
#   'name': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6trNtQUgC8cgbWcqoMYkOR'},
#  {'album_id': 20,
#   'name': 'Views',
#   'release_date': '2016-05-13',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/0G1ffjfFuTUTVjDrVdLimH'},
#  {'album_id': 29,
#   'name': 'F*CK LOVE 3: OVER YOU',
#   'release_date': '2021-07-23',
#   'total_tracks': 29,
#   'url': 'https://open.spotify.com/album/4bZJWQhHKJckFLJuYdvyX2'},
#  {'album_id': 11,
#   'name': 'Evolve',
#   'release_date': '2017-06-23',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/51s30K7a36ORx6AAaPBRRY'},
#  {'album_id': 18,
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': 5,
#   'name': 'Collage EP',
#   'release_date': '2016-11-04',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/22rp3PnM3q2mtTI0OGCzpq'},
#  {'album_id': 18,
#   'name': 'Dreamland (+ Bonus Levels)',
#   'release_date': '2020-08-06',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/0KTj6k94XZh0c6IEMfxeWV'},
#  {'album_id': 13,
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': 16,
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 16,
#   'name': 'Shawn Mendes (Deluxe)',
#   'release_date': '2019-06-19',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/0xzScN8P3hQAz3BT3YYX5w'},
#  {'album_id': 17,
#   'name': 'Back from the Edge',
#   'release_date': '2016-10-28',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/7oiJYvEJHsmYtrgviAVIBD'},
#  {'album_id': 1,
#   'name': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#  {'album_id': 12,
#   'name': 'Fine Line',
#   'release_date': '2019-12-13',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7xV2TzoaVc0ycW7fwBwAml'},
#  {'album_id': 11,
#   'name': 'Future Nostalgia',
#   'release_date': '2020-03-27',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#  {'album_id': 11,
#   'name': 'I Love You.',
#   'release_date': '2013-04-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': 14,
#   'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#  {'album_id': 16,
#   'name': 'Goodbye & Good Riddance',
#   'release_date': '2018-05-23',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2viWIVEItaDlFH2RXWKwS7'},
#  {'album_id': 16,
#   'name': 'x (Deluxe Edition)',
#   'release_date': '2014-06-21',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#  {'album_id': 25,
#   'name': 'Scorpion',
#   'release_date': '2018-06-29',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#  {'album_id': 16,
#   'name': 'x (Deluxe Edition)',
#   'release_date': '2014-06-21',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#  {'album_id': 12,
#   'name': 'Memories...Do Not Open',
#   'release_date': '2017-04-07',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4JPguzRps3kuWDD5GS6oXr'},
#  {'album_id': 18,
#   'name': 'A Night At The Opera (Deluxe Remastered Version)',
#   'release_date': '1975-11-21',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6X9k3hSsvQck2OfKYdBbXr'},
#  {'album_id': 34,
#   'name': 'A Star Is Born Soundtrack',
#   'release_date': '2018-10-05',
#   'total_tracks': 34,
#   'url': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#  {'album_id': 13,
#   'name': 'Hozier',
#   'release_date': '2014-10-07',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/04E0aLUdCHnhnnYrDDvcHq'},
#  {'album_id': 17,
#   'name': "Hollywood's Bleeding",
#   'release_date': '2019-09-06',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4g1ZRSobMefqF6nelkgibi'},
#  {'album_id': 19,
#   'name': 'Purpose (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#  {'album_id': 20,
#   'name': 'Love In The Future (Expanded Edition)',
#   'release_date': '2013-08-30',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/4OTAx9un4e6NfoHuVRiOrC'},
#  {'album_id': 18,
#   'name': '?',
#   'release_date': '2018-03-16',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#  {'album_id': 11,
#   'name': 'Evolve',
#   'release_date': '2017-06-23',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/51s30K7a36ORx6AAaPBRRY'},
#  {'album_id': 12,
#   'name': 'thank u, next',
#   'release_date': '2019-02-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#  {'album_id': 14,
#   'name': 'Birds In The Trap Sing McKnight',
#   'release_date': '2016-09-16',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/42WVQWuf1teDysXiOupIZt'},
#  {'album_id': 11,
#   'name': '17',
#   'release_date': '2017-08-25',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5VdyJkLe3yvOs0l4xXbWp0'},
#  {'album_id': 17,
#   'name': 'Native (Deluxe)',
#   'release_date': '2013-03-26',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/0G0vIGvVlJ3MtXunjqrbMY'},
#  {'album_id': 15,
#   'name': 'Dream Your Life Away (Special Edition)',
#   'release_date': '2014-09-09',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5S9b8euumqMhQbMk0zzQdH'},
#  {'album_id': 14,
#   'name': 'Blurryface',
#   'release_date': '2015-05-15',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3cQO7jp5S9qLBoIVtbkSM1'},
#  {'album_id': 1,
#   'name': 'Wake Me Up',
#   'release_date': '2013-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/37qAVEAZSyRTVFvVRHcwOa'},
#  {'album_id': 14,
#   'name': 'Beauty Behind The Madness',
#   'release_date': '2015-08-28',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/28ZKQMoNBB0etKXZ97G2SN'},
#  {'album_id': 16,
#   'name': 'Luv Is Rage 2',
#   'release_date': '2017-08-25',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/733e1ZfktLSwj96X5rsMeE'},
#  {'album_id': 11,
#   'name': 'Camila',
#   'release_date': '2018-01-12',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2vD3zSQr8hNlg0obNel4TE'},
#  {'album_id': 15,
#   'name': 'The Heist',
#   'release_date': '2012-10-09',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/76FXHQhTuT4QMIxfL09gX8'},
#  {'album_id': 14,
#   'name': 'DAMN.',
#   'release_date': '2017-04-14',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4eLPsYPBmXABThSJ821sqY'},
#  {'album_id': 16,
#   'name': 'All the Little Lights',
#   'release_date': '2012-06-29',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2sRnJq6dfXdqhIflBk0ve1'},
#  {'album_id': 17,
#   'name': 'Dua Lipa (Deluxe)',
#   'release_date': '2017-06-02',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/01sfgrNbnnPUEyz6GZYlt9'},
#  {'album_id': 1,
#   'name': 'Happier',
#   'release_date': '2018-08-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/78EicdHZr5XBWD7llEZ1Jh'},
#  {'album_id': 1,
#   'name': 'One Kiss (with Dua Lipa)',
#   'release_date': '2018-04-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7GEzhoTiqcPYkOprWQu581'},
#  {'album_id': 17,
#   'name': 'ASTROWORLD',
#   'release_date': '2018-08-03',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/41GuZcammIkupMPKH2OJ6I'},
#  {'album_id': 11,
#   'name': 'SOUR',
#   'release_date': '2021-05-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#  {'album_id': 14,
#   'name': 'Encore',
#   'release_date': '2016-08-05',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/02sEJTj1sye1JaqxqpcSCp'},
#  {'album_id': 11,
#   'name': 'SOUR',
#   'release_date': '2021-05-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#  {'album_id': 19,
#   'name': 'Purpose (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#  {'album_id': 15,
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2016-09-23',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2AJaA0is5qbaqFy77tPl7B'},
#  {'album_id': 12,
#   'name': 'Night Visions',
#   'release_date': '2012-09-04',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6htgf3qv7vGcsdxLCDxKp8'},
#  {'album_id': 13,
#   'name': 'Long Way Down',
#   'release_date': '2013-09-17',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3oEqMQVxXfn2jGRaauU2iv'},
#  {'album_id': 24,
#   'name': 'Curtain Call: The Hits (Deluxe Edition)',
#   'release_date': '2005-12-06',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/5qENHeCSlwWpEzb25peRmQ'},
#  {'album_id': 10,
#   'name': 'In The Lonely Hour',
#   'release_date': '2014-05-26',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/08jWgM4vSkTose4blKBWov'},
#  {'album_id': 15,
#   'name': 'MONTERO',
#   'release_date': '2021-09-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6pOiDiuDQqrmo5DbG0ZubR'},
#  {'album_id': 9,
#   'name': 'Peace Is The Mission',
#   'release_date': '2015-06-01',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4DOcG4A40Wf3q2vPNGQwQg'},
#  {'album_id': 16,
#   'name': 'Manic',
#   'release_date': '2020-01-17',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/68enXe5XcJdciSDAZr0Alr'},
#  {'album_id': 11,
#   'name': 'Hot Fuss',
#   'release_date': '2004-06-15',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4undIeGmofnAYKhnDclN1w'},
#  {'album_id': 1,
#   'name': 'Roses (Imanbek Remix)',
#   'release_date': '2019-09-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1p5rgTwzlrhJnSdi93zpbd'},
#  {'album_id': 10,
#   'name': 'Parachutes',
#   'release_date': '2000-07-10',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#  {'album_id': 18,
#   'name': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6trNtQUgC8cgbWcqoMYkOR'},
#  {'album_id': 18,
#   'name': 'Stoney (Deluxe)',
#   'release_date': '2016-12-09',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#  {'album_id': 4,
#   'name': 'Faded',
#   'release_date': '2015-12-04',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5HMjpBO0v78ayq5lreAyDd'},
#  {'album_id': 5,
#   'name': 'Collage EP',
#   'release_date': '2016-11-04',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/22rp3PnM3q2mtTI0OGCzpq'},
#  {'album_id': 11,
#   'name': 'Uptown Special',
#   'release_date': '2015-01-12',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/3vLaOYCNCzngDf8QdBg2V1'},
#  {'album_id': 12,
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5bU1XKYxHhEwukllT20xtk'},
#  {'album_id': 18,
#   'name': 'At Night, Alone.',
#   'release_date': '2016-05-06',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1Tz3Ai1guEFf4hV3d9i17K'},
#  {'album_id': 14,
#   'name': 'JORDI (Deluxe)',
#   'release_date': '2021-06-11',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1pCA38N6MkLlthXtAOvZTU'},
#  {'album_id': 14,
#   'name': 'The Thrill Of It All (Special Edition)',
#   'release_date': '2017-11-03',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3XftSbguntyRTBQaGItmfK'},
#  {'album_id': 15,
#   'name': 'No.6 Collaborations Project',
#   'release_date': '2019-07-12',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3oIFxDIo2fwuk4lwCmFZCx'},
#  {'album_id': 12,
#   'name': 'thank u, next',
#   'release_date': '2019-02-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2fYhqwDWXjbpjaIJPEfKFw'},
#  {'album_id': 13,
#   'name': 'Future Nostalgia',
#   'release_date': '2020-03-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#  {'album_id': 15,
#   'name': 'MONTERO',
#   'release_date': '2021-09-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6pOiDiuDQqrmo5DbG0ZubR'},
#  {'album_id': 16,
#   'name': 'EL ÚLTIMO TOUR DEL MUNDO',
#   'release_date': '2020-11-27',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2d9BCZeAAhiZWPpbX9aPCW'},
#  {'album_id': 13,
#   'name': 'El Dorado',
#   'release_date': '2021-03-26',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/270o30h7cAlEhBnbuSpFZq'},
#  {'album_id': 1,
#   'name': 'Despacito Feat. Justin Bieber (Remix)',
#   'release_date': '2017-04-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Gq2Dme9nesdgoqNNlcN8O'},
#  {'album_id': 18,
#   'name': 'Jungle Rules',
#   'release_date': '2017-07-14',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4c2p3TdN7NcQfCXyueCNnC'},
#  {'album_id': 18,
#   'name': '?',
#   'release_date': '2018-03-16',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#  {'album_id': 8,
#   'name': 'BE',
#   'release_date': '2020-11-20',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/6nYfHQnvkvOTNHnOhDT3sr'},
#  {'album_id': 16,
#   'name': 'Please Excuse Me for Being Antisocial',
#   'release_date': '2019-12-06',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/52u4anZbHd6UInnmHRFzba'},
#  {'album_id': 40,
#   'name': "(What's The Story) Morning Glory? (Deluxe Edition) [Remastered]",
#   'release_date': '1995-10-02',
#   'total_tracks': 40,
#   'url': 'https://open.spotify.com/album/6ozp33PI3p9AdddB6ZL3xQ'},
#  {'album_id': 9,
#   'name': '24K Magic',
#   'release_date': '2016-11-17',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4PgleR09JVnm3zY1fW3XBA'},
#  {'album_id': 12,
#   'name': 'This Is Acting',
#   'release_date': '2016-01-29',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/77jAfTh3KH9K2reMOmTgOh'},
#  {'album_id': 16,
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2017-04-20',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3wBabo4pmzsYjALMSKY7Iq'},
#  {'album_id': 18,
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': 20,
#   'name': 'The Eminem Show',
#   'release_date': '2002-05-26',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#  {'album_id': 12,
#   'name': 'Handwritten',
#   'release_date': '2015-04-14',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0CnQ0JQajNswRjPkNYVG8m'},
#  {'album_id': 13,
#   'name': '2014 Forest Hills Drive',
#   'release_date': '2014-12-09',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/7viNUmZZ8ztn2UB4XB3jIL'},
#  {'album_id': 1,
#   'name': 'See You Again (feat. Charlie Puth)',
#   'release_date': '2015-03-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/02tTjKlh9iQ5jlWYPbKLJZ'},
#  {'album_id': 10,
#   'name': 'Doo-Wops & Hooligans',
#   'release_date': '2010-10-05',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1uyf3l2d4XYwiEqAb7t7fX'},
#  {'album_id': 17,
#   'name': 'I met you when I was 18. (the playlist)',
#   'release_date': '2018-05-31',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/7lqieLm717j9Z8JrG7POkS'},
#  {'album_id': 11,
#   'name': 'Lukas Graham',
#   'release_date': '2016-04-01',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4rFrdkSWs0dtj0rWPzOk1v'},
#  {'album_id': 12,
#   'name': 'We Sing. We Dance. We Steal Things.',
#   'release_date': '2008-05-12',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/04G0YylSjvDQZrjOfE5jA5'},
#  {'album_id': 13,
#   'name': 'Nevermind (Remastered)',
#   'release_date': '1991-09-26',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#  {'album_id': 16,
#   'name': 'Red Pill Blues (Deluxe)',
#   'release_date': '2018-06-15',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3ThQ5dvf9wlqB0C7evh5nH'},
#  {'album_id': 11,
#   'name': '21',
#   'release_date': '2011-01-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#  {'album_id': 15,
#   'name': 'VIDA',
#   'release_date': '2019-02-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5C0YLr4OoRGFDaqdMQmkeH'},
#  {'album_id': 10,
#   'name': 'Viva La Vida or Death and All His Friends',
#   'release_date': '2008-05-26',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#  {'album_id': 12,
#   'name': 'V',
#   'release_date': '2014-09-02',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2Auw0pTT6EcQdvHNimhLQI'},
#  {'album_id': 13,
#   'name': 'BLAME IT ON BABY',
#   'release_date': '2020-04-17',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/623PL2MBg50Br5dLXC9E9e'},
#  {'album_id': 16,
#   'name': 'Youngblood (Deluxe)',
#   'release_date': '2018-06-15',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2D0Hi3Jj6RFnpWDcSa0Otu'},
#  {'album_id': 13,
#   'name': 'TROLLS (Original Motion Picture Soundtrack)',
#   'release_date': '2016-09-23',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/65ayND23IInUPHJKsaAqe7'},
#  {'album_id': 1,
#   'name': 'Heathens',
#   'release_date': '2016-06-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3J8W9AOjQhnBLCX33m3atT'},
#  {'album_id': 14,
#   'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#  {'album_id': 12,
#   'name': 'Night Visions',
#   'release_date': '2012-09-04',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6htgf3qv7vGcsdxLCDxKp8'},
#  {'album_id': 18,
#   'name': 'Stoney (Deluxe)',
#   'release_date': '2016-12-09',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5s0rmjP8XOPhP6HhqOhuyC'},
#  {'album_id': 12,
#   'name': 'Nine Track Mind',
#   'release_date': '2016-01-29',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3kndSWeE2IYOrZEToZrHEV'},
#  {'album_id': 18,
#   'name': 'Jazz (Deluxe Remastered Version)',
#   'release_date': '1978-11-10',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/21HMAUrbbYSj9NiPPlGumy'},
#  {'album_id': 13,
#   'name': 'Voicenotes',
#   'release_date': '2018-05-11',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0mZIUXje90JtHxPNzWsJNR'},
#  {'album_id': 14,
#   'name': 'Escape (Bonus Track Version)',
#   'release_date': '1981',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/43wpzak9OmQfrjyksuGwp0'},
#  {'album_id': 7,
#   'name': 'FRIENDS KEEP SECRETS',
#   'release_date': '2018-12-07',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/7dQ734EW0iLvQfF6vBFNiZ'},
#  {'album_id': 8,
#   'name': '7 EP',
#   'release_date': '2019-06-21',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/4IRiXE5NROxknUSAUSjMoO'},
#  {'album_id': 11,
#   'name': 'A Rush of Blood to the Head',
#   'release_date': '2002-08-08',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/0RHX9XECH8IVI3LNgWDpmQ'},
#  {'album_id': 14,
#   'name': 'Me 4 U',
#   'release_date': '2015-10-16',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1QwWTLYn9dntAj7l9FRJwY'},
#  {'album_id': 15,
#   'name': 'The Game (Deluxe Remastered Version)',
#   'release_date': '1980-06-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6wPXUmYJ9mOWrKlLzZ5cCa'},
#  {'album_id': 14,
#   'name': 'Blurryface',
#   'release_date': '2015-05-15',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3cQO7jp5S9qLBoIVtbkSM1'},
#  {'album_id': 14,
#   'name': 'Beauty Behind The Madness',
#   'release_date': '2015-08-28',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/28ZKQMoNBB0etKXZ97G2SN'},
#  {'album_id': 19,
#   'name': 'Purpose (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6Fr2rQkZ383FcMqFyT7yPr'},
#  {'album_id': 16,
#   'name': 'Heaven & Hell',
#   'release_date': '2020-09-18',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/26c7MmQ4w8EAvVLb4jilaM'},
#  {'album_id': 20,
#   'name': '1000 Forms Of Fear (Deluxe Version)',
#   'release_date': '2015-05-04',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/6FdNvoO5sF4EKwCX9je1MH'},
#  {'album_id': 13,
#   'name': 'Invasion of Privacy',
#   'release_date': '2018-04-06',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4KdtEKjY3Gi0mKiSdy96ML'},
#  {'album_id': 15,
#   'name': 'Divinely Uninspired To A Hellish Extent (Extended Edition)',
#   'release_date': '2019-11-22',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2wiPF3m0ylst0JSk1IvZL8'},
#  {'album_id': 17,
#   'name': "Hollywood's Bleeding",
#   'release_date': '2019-09-06',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4g1ZRSobMefqF6nelkgibi'},
#  {'album_id': 12,
#   'name': 'A Place We Knew',
#   'release_date': '2019-03-22',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/61G7KL6rpj167r6H4CzS8C'},
#  {'album_id': 10,
#   'name': 'Nicotine',
#   'release_date': '2020-03-26',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0D7yJonn41qsrIQ7YdWk2z'},
#  {'album_id': 17,
#   'name': 'Carte Blanche',
#   'release_date': '2019-07-25',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/2MFS6WG6jnPAgvJpV3PehR'},
#  {'album_id': 1,
#   'name': 'This Is What You Came For',
#   'release_date': '2016-04-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3pEgGUv379EDinvg1TN7Kt'},
#  {'album_id': 18,
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': 15,
#   'name': 'Hybrid Theory (Bonus Edition)',
#   'release_date': '2000-10-24',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6hPkbAV3ZXpGZBGUvL6jVM'},
#  {'album_id': 11,
#   'name': '25',
#   'release_date': '2016-06-24',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/0K4pIOOsfJ9lK8OjrZfXzd'},
#  {'album_id': 18,
#   'name': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6trNtQUgC8cgbWcqoMYkOR'},
#  {'album_id': 1,
#   'name': 'Cold Water',
#   'release_date': '2016-07-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Kmo85mapQ2wTaCAHBkKsK'},
#  {'album_id': 14,
#   'name': '=',
#   'release_date': '2021-10-29',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/32iAEBstCjauDhyKpGjTuq'},
#  {'album_id': 10,
#   'name': 'Torches',
#   'release_date': '2011-05-23',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7Kmmw7Z5D2UD5MVwdm10sT'},
#  {'album_id': 17,
#   'name': 'Dua Lipa (Deluxe)',
#   'release_date': '2017-06-02',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/01sfgrNbnnPUEyz6GZYlt9'},
#  {'album_id': 1,
#   'name': 'death bed (coffee for your head)',
#   'release_date': '2020-02-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2p9gK2BcdrloHNJwarc9gc'},
#  {'album_id': 14,
#   'name': 'Planet Her',
#   'release_date': '2021-06-25',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1nAQbHeOWTfQzbOoFrvndW'},
#  {'album_id': 13,
#   'name': '54+1',
#   'release_date': '2019-03-22',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3pHFjWCK7d5YLtEuFwfR5N'},
#  {'album_id': 1,
#   'name': 'ROXANNE',
#   'release_date': '2019-10-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6HJDrXs0hpebaRFKA1sF90'},
#  {'album_id': 29,
#   'name': 'Icarus Falls',
#   'release_date': '2018-12-14',
#   'total_tracks': 29,
#   'url': 'https://open.spotify.com/album/1DF9B2hfwX4EdgEFwGcRwh'},
#  {'album_id': 19,
#   'name': 'Fifty Shades Darker (Original Motion Picture Soundtrack)',
#   'release_date': '2017-02-10',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/5VML6S956h4YfoYPooqLEi'},
#  {'album_id': 10,
#   'name': 'Unorthodox Jukebox',
#   'release_date': '2012-12-07',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/58ufpQsJ1DS5kq4hhzQDiI'},
#  {'album_id': 10,
#   'name': 'In The Lonely Hour',
#   'release_date': '2014-01-01',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/2Jg7JZ0ZXOGje1bkq7CVgK'},
#  {'album_id': 11,
#   'name': 'Pray for the Wicked',
#   'release_date': '2018-06-22',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6ApYSpXF8GxZAgBTHDzYge'},
#  {'album_id': 20,
#   'name': 'The Eminem Show',
#   'release_date': '2002-05-26',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/2cWBwpqMsDJC1ZUwz813lo'},
#  {'album_id': 12,
#   'name': 'Appetite For Destruction',
#   'release_date': '1987-07-21',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/28yHV3Gdg30AiB8h8em1eW'},
#  {'album_id': 22,
#   'name': 'Delirium (Deluxe)',
#   'release_date': '2015-11-06',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/20Ol6zZ0nLlc5EGTH1zA0j'},
#  {'album_id': 16,
#   'name': 'What Is Love? (Deluxe Edition)',
#   'release_date': '2018-11-30',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1MvF4ulZKH7SaDQs9rE5nc'},
#  {'album_id': 10,
#   'name': 'Toto IV',
#   'release_date': '1982-04-08',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/62U7xIHcID94o20Of5ea4D'},
#  {'album_id': 11,
#   'name': 'Synchronicity (Remastered 2003)',
#   'release_date': '1983-06-17',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5W9OT0a5iZlBr83a9WMKFY'},
#  {'album_id': 1,
#   'name': 'Silence',
#   'release_date': '2017-08-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2bw00gRKNKbTFOqCkohbSh'},
#  {'album_id': 16,
#   'name': 'KG0516',
#   'release_date': '2021-03-26',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5CS8E6JVACItYto4OOJoPW'},
#  {'album_id': 14,
#   'name': 'DNCE',
#   'release_date': '2016-11-18',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3Wv4X8OA65pGpFzBkuUgAh'},
#  {'album_id': 1,
#   'name': 'The Middle',
#   'release_date': '2018-01-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7nEiwcUSwycvC77kZ9ub7c'},
#  {'album_id': 14,
#   'name': 'Beauty Behind The Madness',
#   'release_date': '2015-08-28',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0P3oVJBFOv3TDXlYRhGL7s'},
#  {'album_id': 25,
#   'name': 'Scorpion',
#   'release_date': '2018-06-29',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#  {'album_id': 14,
#   'name': 'Vibras',
#   'release_date': '2018-05-25',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5kprdYds6oZb4iSldfflOT'},
#  {'album_id': 12,
#   'name': '7/27 (Deluxe)',
#   'release_date': '2016-05-27',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0pF0oyuPNdOObniB1Ng0kW'},
#  {'album_id': 15,
#   'name': 'American Teen',
#   'release_date': '2017-04-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6kf46HbnYCZzP6rjvQHYzg'},
#  {'album_id': 16,
#   'name': 'Justice',
#   'release_date': '2021-03-19',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#  {'album_id': 1,
#   'name': 'FRIENDS',
#   'release_date': '2018-02-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1BmxOYHjQv1dKZRr13YRZM'},
#  {'album_id': 17,
#   'name': 'FUTURE',
#   'release_date': '2017-08-04',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4YtTX4GPvBvewbJvBfXCS2'},
#  {'album_id': 7,
#   'name': 'us',
#   'release_date': '2016-03-25',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/3L0H4RjVXpEkwfDgi3XOdf'},
#  {'album_id': 11,
#   'name': '17',
#   'release_date': '2017-08-25',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5VdyJkLe3yvOs0l4xXbWp0'},
#  {'album_id': 1,
#   'name': 'HIGHEST IN THE ROOM',
#   'release_date': '2019-10-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2uDTi1PlpSpvAv7IRAoAEU'},
#  {'album_id': 12,
#   'name': 'Making Mirrors',
#   'release_date': '2011-01-01',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1HjSyGjmLNjRAKgT9t1cna'},
#  {'album_id': 1,
#   'name': "It Ain't Me",
#   'release_date': '2017-02-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4VNy5ifZtW3E9SgffbGEti'},
#  {'album_id': 12,
#   'name': 'TALKING IS HARD',
#   'release_date': '2014-12-02',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3mNoFlD1wsoXfkljfFzExT'},
#  {'album_id': 18,
#   'name': 'Speak Your Mind (Deluxe)',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/7lPoGKpCGgdKFAxpudhAH5'},
#  {'album_id': 12,
#   'name': 'Fine Line',
#   'release_date': '2019-12-13',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7xV2TzoaVc0ycW7fwBwAml'},
#  {'album_id': 15,
#   'name': 'No.6 Collaborations Project',
#   'release_date': '2019-07-12',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3oIFxDIo2fwuk4lwCmFZCx'},
#  {'album_id': 16,
#   'name': 'Perception',
#   'release_date': '2017-10-06',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1KOmHyNLuOe5YrPhD3Juuf'},
#  {'album_id': 16,
#   'name': 'I AM...SASHA FIERCE',
#   'release_date': '2008-11-14',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/23Y5wdyP5byMFktZf8AcWU'},
#  {'album_id': 11,
#   'name': '"Awaken, My Love!"',
#   'release_date': '2016-12-02',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4xnq1L6P551Qcb9gBXNMK7'},
#  {'album_id': 30,
#   'name': 'Thriller 25 Super Deluxe Edition',
#   'release_date': '2008-02-08',
#   'total_tracks': 30,
#   'url': 'https://open.spotify.com/album/1C2h7mLntPSeVYciMRTF4a'},
#  {'album_id': 23,
#   'name': 'Nothing but the Beat 2.0',
#   'release_date': '2011-08-24',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/5aprcHwM1KJhaY9Kbxkfkn'},
#  {'album_id': 11,
#   'name': '21',
#   'release_date': '2011-01-19',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#  {'album_id': 10,
#   'name': 'Hunting High and Low',
#   'release_date': '1985-06-01',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1ER3B6zev5JEAaqhnyyfbf'},
#  {'album_id': 1,
#   'name': 'In My Mind',
#   'release_date': '2018-06-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1c79SozES9Eb3Lzf9KVaIa'},
#  {'album_id': 15,
#   'name': 'American Teen',
#   'release_date': '2017-04-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6kf46HbnYCZzP6rjvQHYzg'},
#  {'album_id': 15,
#   'name': 'Dangerous Woman',
#   'release_date': '2016-05-20',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3OZgEywV4krCZ814pTJWr7'},
#  {'album_id': 13,
#   'name': 'Everybody',
#   'release_date': '2017-05-05',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/1HiN2YXZcc3EjmVZ4WjfBk'},
#  {'album_id': 6,
#   'name': 'All Your Fault: Pt. 2',
#   'release_date': '2017-08-11',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6t5D6LEgHxqUVOxJItkzfb'},
#  {'album_id': 1,
#   'name': 'A Thousand Years',
#   'release_date': '2011-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/15yvc643iYfQtb6zh9NEJo'},
#  {'album_id': 14,
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': 16,
#   'name': 'What Is Love? (Deluxe Edition)',
#   'release_date': '2018-11-30',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1MvF4ulZKH7SaDQs9rE5nc'},
#  {'album_id': 1,
#   'name': 'In the Name of Love',
#   'release_date': '2016-07-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1FOJ5IXGXe8dl0cXvCU6wK'},
#  {'album_id': 16,
#   'name': 'Hot Space (Deluxe Remastered Version)',
#   'release_date': '1982-05-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/0xc5IpJM39eEEYSKDrm5kf'},
#  {'album_id': 18,
#   'name': '?',
#   'release_date': '2018-03-16',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2Ti79nwTsont5ZHfdxIzAm'},
#  {'album_id': 10,
#   'name': 'Merry Christmas',
#   'release_date': '1994-10-28',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/61ulfFSmmxMhc2wCdmdMkN'},
#  {'album_id': 12,
#   'name': 'Overexposed',
#   'release_date': '2021-06-20',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5x7JzoE4A3DwwU6FPt8qws'},
#  {'album_id': 4,
#   'name': 'The Days / Nights',
#   'release_date': '2014-01-01',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/0h2knr6qpiAq0tV5ri5JMF'},
#  {'album_id': 14,
#   'name': 'Legendary',
#   'release_date': '2019-06-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/6hHIX3lfGKnZ2ji41YZMVV'},
#  {'album_id': 16,
#   'name': 'ANTI (Deluxe)',
#   'release_date': '2016-01-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/19O3rXe4nDu9YDcc2tOQVn'},
#  {'album_id': 10,
#   'name': 'Unorthodox Jukebox',
#   'release_date': '2012-12-10',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7KBjLhk3IM27k3ry4vBk3i'},
#  {'album_id': 15,
#   'name': 'Bad Blood',
#   'release_date': '2013-01-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/64fQ94AVziavTPdnkCS6Nj'},
#  {'album_id': 22,
#   'name': 'More Life',
#   'release_date': '2017-03-18',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/1lXY618HWkwYKJWBRYR4MK'},
#  {'album_id': 15,
#   'name': 'Sweetener',
#   'release_date': '2018-08-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3tx8gQqWbGwqIGZHqDNrGe'},
#  {'album_id': 23,
#   'name': 'Grateful',
#   'release_date': '2017-06-22',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3HhZbSJdhOqMSaRbEt3gtw'},
#  {'album_id': 1,
#   'name': 'everything i wanted',
#   'release_date': '2019-11-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#  {'album_id': 1,
#   'name': 'Wolves',
#   'release_date': '2017-10-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5gQZvWM1o8NkQndueJtZcP'},
#  {'album_id': 9,
#   'name': '24K Magic',
#   'release_date': '2016-11-17',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4PgleR09JVnm3zY1fW3XBA'},
#  {'album_id': 14,
#   'name': 'Happiness Begins',
#   'release_date': '2019-06-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1Uf67JAtkVWfdydzFFqNF2'},
#  {'album_id': 14,
#   'name': 'Elephant',
#   'release_date': '2003-04-01',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/6D9urpsOWWKtYvF6PaorGE'},
#  {'album_id': 9,
#   'name': 'Hotel California (2013 Remaster)',
#   'release_date': '1976-12-08',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/2widuo17g5CEC66IbzveRu'},
#  {'album_id': 1,
#   'name': 'Con Calma',
#   'release_date': '2019-01-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1otwHKoQ5KPaiekpYk4tWh'},
#  {'album_id': 15,
#   'name': 'So Good',
#   'release_date': '2017-03-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5YLRVHDVRw3QqWbeTGpC5B'},
#  {'album_id': 7,
#   'name': 'Chosen',
#   'release_date': '2017-12-08',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2qJw6w5XwQO0PQlSWPu7Tw'},
#  {'album_id': 20,
#   'name': 'Views',
#   'release_date': '2016-05-06',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/40GMAhriYJRO1rsY4YdrZb'},
#  {'album_id': 1,
#   'name': 'Callaita',
#   'release_date': '2019-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/06S3Qjh4QWLtn6c7CVhYh7'},
#  {'album_id': 16,
#   'name': 'The Lockdown Sessions',
#   'release_date': '2021-10-22',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/7wHczdY0ek3FHnfVhk10om'},
#  {'album_id': 16,
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 10,
#   'name': 'The Best Of Earth, Wind & Fire Vol. 1',
#   'release_date': '1978-11-23',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/2FW0uQ4WL25umm5p2VrZO7'},
#  {'album_id': 16,
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 10,
#   'name': 'Harry Styles',
#   'release_date': '2017-05-12',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/1FZKIm3JVDCxTchXDo5jOV'},
#  {'album_id': 15,
#   'name': 'Motion',
#   'release_date': '2014-10-31',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/48zisMeiXniWLzOQghbPqS'},
#  {'album_id': 11,
#   'name': '17',
#   'release_date': '2017-08-25',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5VdyJkLe3yvOs0l4xXbWp0'},
#  {'album_id': 1,
#   'name': 'Look At Me!',
#   'release_date': '2017-02-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3cyyJALrHc8LawnQNFYRWL'},
#  {'album_id': 12,
#   'name': 'Narrated For You',
#   'release_date': '2018-11-16',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6jKZplJpy21R5lHaYHHjmZ'},
#  {'album_id': 13,
#   'name': 'Meteora',
#   'release_date': '2003-03-24',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4Gfnly5CzMJQqkUFfoHaP3'},
#  {'album_id': 13,
#   'name': 'Know-It-All (Deluxe)',
#   'release_date': '2015-11-13',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3rDbA12I5duZnlwakqDdZa'},
#  {'album_id': 13,
#   'name': 'Currents',
#   'release_date': '2015-07-17',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/79dL7FLiJFOO0EoehUHQBv'},
#  {'album_id': 1,
#   'name': 'MIA (feat. Drake)',
#   'release_date': '2018-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0p0W4RXcnc59jgatcdZozO'},
#  {'album_id': 17,
#   'name': "When It's Dark Out",
#   'release_date': '2015-12-04',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/09Q3WwGYsQe5ognkvVkmCu'},
#  {'album_id': 14,
#   'name': 'Strange Trails',
#   'release_date': '2015-04-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3yoNZlqerJnsnMN5EDwwBS'},
#  {'album_id': 18,
#   'name': 'Mind Of Mine (Deluxe Edition)',
#   'release_date': '2016-03-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5amj9zNeZ3B2EdpBgXrOZ0'},
#  {'album_id': 17,
#   'name': 'Goodbye & Good Riddance',
#   'release_date': '2018-12-10',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/6tkjU4Umpo79wwkgPMV3nZ'},
#  {'album_id': 10,
#   'name': 'Back In Black',
#   'release_date': '1980-07-25',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6mUdeDZCsExyJLMdAfDuwh'},
#  {'album_id': 1,
#   'name': 'Ride It',
#   'release_date': '2019-07-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4zOhjJfe0dwqsNdDYk622E'},
#  {'album_id': 1,
#   'name': 'Happy (From "Despicable Me 2")',
#   'release_date': '2014-01-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1tXHmyPSfn6gJHkAifLGDj'},
#  {'album_id': 19,
#   'name': 'Save Me, San Francisco (Golden Gate Edition)',
#   'release_date': '2010-12-01',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/1CwXS6MAz8Wo7K4TzW9iuR'},
#  {'album_id': 16,
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': 1,
#   'name': 'WAP (feat. Megan Thee Stallion)',
#   'release_date': '2020-08-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2ogiazbrNEx0kQHGl5ZBTQ'},
#  {'album_id': 13,
#   'name': 'ANTI',
#   'release_date': '2016-01-28',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3Q149ZH46Z0f3oDR7vlDYV'},
#  {'album_id': 17,
#   'name': 'B4 The Storm',
#   'release_date': '2020-08-28',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/2vGU0DOcfsDee0euvhl1iZ'},
#  {'album_id': 7,
#   'name': 'Suncity',
#   'release_date': '2018-10-18',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2Qxc2NJ7yPKVFRWi3llRr2'},
#  {'album_id': 11,
#   'name': "Don't Kill the Magic",
#   'release_date': '2014-06-25',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/0RZ4Ct4vegYBmL9g88TBNi'},
#  {'album_id': 8,
#   'name': 'OASIS',
#   'release_date': '2019-06-28',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/6ylFfzx32ICw4L1A7YWNLN'},
#  {'album_id': 15,
#   'name': 'Certified Hitmaker',
#   'release_date': '2020-02-06',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2a1AHCq835BXUcX1aTTWqQ'},
#  {'album_id': 14,
#   'name': 'New English',
#   'release_date': '2016-06-26',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/0cHT4ll3sEPyFFWoFuibMl'},
#  {'album_id': 15,
#   'name': 'Sweet Talker (Deluxe Version)',
#   'release_date': '2014-10-14',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2rDIivxBafNKpgRqlzIRSb'},
#  {'album_id': 14,
#   'name': 'Peace Is The Mission (Extended)',
#   'release_date': '2015-11-27',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1zHfDPtlXk2Biq8iVS1I3F'},
#  {'album_id': 15,
#   'name': 'More Than You Know',
#   'release_date': '2017-07-28',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6Ei5WWek37m1x9AjpSXTcJ'},
#  {'album_id': 14,
#   'name': 'Black Panther The Album Music From And Inspired By',
#   'release_date': '2018-02-09',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3pLdWdkj83EYfDN6H2N8MR'},
#  {'album_id': 1,
#   'name': 'Stay',
#   'release_date': '2017-02-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1I4W7JKzYbl8VKRfD61DIS'},
#  {'album_id': 1,
#   'name': 'Starving',
#   'release_date': '2016-07-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/18pR217SWwBjODSRWFBw0I'},
#  {'album_id': 18,
#   'name': 'The Marshall Mathers LP',
#   'release_date': '2000-05-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6t7956yu5zYf5A829XRiHC'},
#  {'album_id': 13,
#   'name': 'Oral Fixation, Vol. 2 (Expanded Edition)',
#   'release_date': '2005-11-28',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5ppnlEoj4HdRRdRihnY3jU'},
#  {'album_id': 12,
#   'name': 'everything means nothing',
#   'release_date': '2020-08-21',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4UxlLk460BnmQlRV3WiORh'},
#  {'album_id': 1,
#   'name': 'Young, Wild & Free (feat. Bruno Mars)',
#   'release_date': '2011-10-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/11Bkx3E99vf0IlYPND61LJ'},
#  {'album_id': 1,
#   'name': 'Scared to Be Lonely',
#   'release_date': '2017-01-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2v9rQe4F8fVSh5v8bAq0jF'},
#  {'album_id': 13,
#   'name': 'Graduation',
#   'release_date': '2007-09-11',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3SZr5Pco2oqKFORCP3WNj9'},
#  {'album_id': 13,
#   'name': 'New Eyes',
#   'release_date': '2014-06-02',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4a6DxkhmMvvEdPXxm4ergN'},
#  {'album_id': 10,
#   'name': 'Without Warning',
#   'release_date': '2017-10-30',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0MV1yCXcNNQBfwApqAVkH0'},
#  {'album_id': 7,
#   'name': 'My Dear Melancholy,',
#   'release_date': '2018-03-30',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/4qZBW3f2Q8y0k1A84d4iAO'},
#  {'album_id': 10,
#   'name': 'Woodstock',
#   'release_date': '2017-06-16',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/4VzzEviJGYUtAeSsJlI9QB'},
#  {'album_id': 29,
#   'name': 'Songs About Jane: 10th Anniversary Edition',
#   'release_date': '2002',
#   'total_tracks': 29,
#   'url': 'https://open.spotify.com/album/5zClcGCSWj926AMjvBNSLc'},
#  {'album_id': 1,
#   'name': 'Dancing With A Stranger (with Normani)',
#   'release_date': '2019-01-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1V9oE8bVilClrk5naqyyvL'},
#  {'album_id': 58,
#   'name': 'Rumours (Super Deluxe)',
#   'release_date': '1977-02-04',
#   'total_tracks': 58,
#   'url': 'https://open.spotify.com/album/0BwWUstDMUbgq2NYONRqlu'},
#  {'album_id': 17,
#   'name': 'Global Warming: Meltdown (Deluxe Version)',
#   'release_date': '2012',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/2F7tejLHzTqFq2XLol9ZGy'},
#  {'album_id': 25,
#   'name': 'Scorpion',
#   'release_date': '2018-06-29',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#  {'album_id': 7,
#   'name': 'Nervous System',
#   'release_date': '2017-07-28',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/1qyjZGIeeLJlXbYWuoloWj'},
#  {'album_id': 14,
#   'name': 'Positions',
#   'release_date': '2020-10-30',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3euz4vS7ezKGnNSwgyvKcd'},
#  {'album_id': 10,
#   'name': 'Highway to Hell',
#   'release_date': '1979-07-27',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/10v912xgTZbjAtYfyKWJCS'},
#  {'album_id': 16,
#   'name': 'Red Pill Blues (Deluxe)',
#   'release_date': '2018-06-15',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3ThQ5dvf9wlqB0C7evh5nH'},
#  {'album_id': 15,
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2016-09-23',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/2AJaA0is5qbaqFy77tPl7B'},
#  {'album_id': 12,
#   'name': 'V',
#   'release_date': '2014-09-02',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2Auw0pTT6EcQdvHNimhLQI'},
#  {'album_id': 15,
#   'name': 'Dangerous Woman',
#   'release_date': '2016-05-20',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3OZgEywV4krCZ814pTJWr7'},
#  {'album_id': 10,
#   'name': 'Slippery When Wet',
#   'release_date': '1986-08-16',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0kBfgEilUFCMIQY5IOjG4t'},
#  {'album_id': 25,
#   'name': 'La 167',
#   'release_date': '2021-10-01',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/0T6QxdJZwYrXPHd829SnqK'},
#  {'album_id': 18,
#   'name': 'We Love You Tecca',
#   'release_date': '2019-08-30',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1I6FpscJIfwf4T56VxGVsB'},
#  {'album_id': 22,
#   'name': 'Death Race For Love',
#   'release_date': '2019-03-08',
#   'total_tracks': 22,
#   'url': 'https://open.spotify.com/album/1GYVNOzwhx1nMcIJDogSNp'},
#  {'album_id': 14,
#   'name': 'Sadnecessary',
#   'release_date': '2014-06-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/5D20ZzsNB377xbshIFP9Nb'},
#  {'album_id': 17,
#   'name': 'Recovery',
#   'release_date': '2010-06-18',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/47BiFcV59TQi2s9SkBo2pb'},
#  {'album_id': 13,
#   'name': 'X&Y',
#   'release_date': '2005-06-07',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4E7bV0pzG0LciBSWTszra6'},
#  {'album_id': 12,
#   'name': '30',
#   'release_date': '2021-11-19',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/21jF5jlMtzo94wbxmJ18aa'},
#  {'album_id': 1,
#   'name': 'Calma (Remix)',
#   'release_date': '2018-10-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1tFnP9PwIMeMIuj92mfswZ'},
#  {'album_id': 12,
# ...
#  {'album_id': 9,
#   'name': 'Dynasty',
#   'release_date': '1979-03-23',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/4FA68GsblSfvKZZRfM1tI1'},
#  {'album_id': 29,
#   'name': 'Ladies And Gentlemen... The Best Of George Michael',
#   'release_date': '1998-11-09',
#   'total_tracks': 29,
#   'url': 'https://open.spotify.com/album/3coLNlyStg9h7f8CZ103Rl'},
#  {'album_id': 11,
#   'name': 'FINAL (Vol.1)',
#   'release_date': '2021-09-17',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/61a4XyIj98CGrUnKy8Hu4Z'},
#  {'album_id': 12,
#   'name': 'Teenage Dream',
#   'release_date': '2010-01-01',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/2eQMC9nJE3f3hCNKlYYHL1'},
#  {'album_id': 15,
#   'name': 'MONTERO',
#   'release_date': '2021-09-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6pOiDiuDQqrmo5DbG0ZubR'},
#  {'album_id': 10,
#   'name': 'Back In Black',
#   'release_date': '1980-07-25',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6mUdeDZCsExyJLMdAfDuwh'},
#  {'album_id': 13,
#   'name': 'Sin Miedo (del Amor y Otros Demonios) ∞',
#   'release_date': '2020-12-04',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/00wSTrFxoSzA7eeS1UxHgd'},
#  {'album_id': 8,
#   'name': 'THE ALBUM',
#   'release_date': '2020-10-02',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/71O60S5gIJSIAhdnrDIh3N'},
#  {'album_id': 16,
#   'name': 'The Rising Tied',
#   'release_date': '2005-11-21',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5v4Vx9loqMQCS3J7OmP9pa'},
#  {'album_id': 12,
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': 12,
#   'name': 'Favourite Worst Nightmare (Standard Version)',
#   'release_date': '2007-04-24',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6rsQnwaoJHxXJRCDBPkBRw'},
#  {'album_id': 48,
#   'name': 'The Very Best of Bonnie Tyler',
#   'release_date': '2009-03-26',
#   'total_tracks': 48,
#   'url': 'https://open.spotify.com/album/0VJI3wpebzRyVHq0eZQidb'},
#  {'album_id': 10,
#   'name': 'American Pie',
#   'release_date': '1971',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/10jsW2NYd9blCrDITMh2zS'},
#  {'album_id': 24,
#   'name': 'Lungs (Deluxe Edition)',
#   'release_date': '2009',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/2FgknX5e7fJlriQtxvpLhZ'},
#  {'album_id': 19,
#   'name': 'Pink Friday ... Roman Reloaded',
#   'release_date': '2011-01-01',
#   'total_tracks': 19,
#   'url': 'https://open.spotify.com/album/6OfCOPtcPuhlAovGJ52uZO'},
#  {'album_id': 13,
#   'name': "A Fever You Can't Sweat Out",
#   'release_date': '2005-09-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2YeOhhJg3OWpN0F1VYPxtW'},
#  {'album_id': 15,
#   'name': 'Under The Mistletoe (Deluxe Edition)',
#   'release_date': '2011-01-01',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/63MKT9hwmiMFFdFp5SdB1p'},
#  {'album_id': 23,
#   'name': 'Un Verano Sin Ti',
#   'release_date': '2022-05-06',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#  {'album_id': 23,
#   'name': 'Un Verano Sin Ti',
#   'release_date': '2022-05-06',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/3RQQmkQEvNCY4prGKE6oc5'},
#  {'album_id': 12,
#   'name': 'Rise And Fall, Rage And Grace',
#   'release_date': '2008-06-17',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/67v63ubEsvDUQkYMzI7A9t'},
#  {'album_id': 16,
#   'name': 'Queen Of The Clouds',
#   'release_date': '2014-01-01',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/47C7w4o1resDhr7jvYEpxE'},
#  {'album_id': 13,
#   'name': 'Too Low For Zero',
#   'release_date': '1983-05-30',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0OmYuz9hwn1XoqmDaU0yJ7'},
#  {'album_id': 30,
#   'name': 'Elton John',
#   'release_date': '1970-04-10',
#   'total_tracks': 30,
#   'url': 'https://open.spotify.com/album/69P9Ro0W286yLFgYwrGVN0'},
#  {'album_id': 9,
#   'name': 'Madman Across The Water',
#   'release_date': '1971-11-05',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/2OZbaW9tgO62ndm375lFZr'},
#  {'album_id': 13,
#   'name': 'Voulez-Vous',
#   'release_date': '1979',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/7iLuHJkrb9KHPkMgddYigh'},
#  {'album_id': 12,
#   'name': 'If You Can Believe Your Eyes & Ears',
#   'release_date': '1966-03',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/76oMr4Y2pOtcrvZLc2ZikF'},
#  {'album_id': 32,
#   'name': 'Blur (Special Edition)',
#   'release_date': '1997-02-10',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/7HvIrSkKGJCzd8AKyjTJ6Q'},
#  {'album_id': 10,
#   'name': 'Oracular Spectacular',
#   'release_date': '2007-12-14',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6mm1Skz3JE6AXneya9Nyiv'},
#  {'album_id': 10,
#   'name': 'Oracular Spectacular',
#   'release_date': '2007-12-14',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/6mm1Skz3JE6AXneya9Nyiv'},
#  {'album_id': 12,
#   'name': 'Diana Ross Presents The Jackson 5',
#   'release_date': '1969-12-18',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/51uoKRa8vT5SULrlF8s2t1'},
#  {'album_id': 12,
#   'name': 'Just As I Am',
#   'release_date': '1971-05-01',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6N8uPmDqbgXD3ztkCCfxoo'},
#  {'album_id': 25,
#   'name': 'How Can You Mend A Broken Heart',
#   'release_date': '2020-12-11',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/4vAhQeeWkSjVn0p5GAaLBx'},
#  {'album_id': 25,
#   'name': 'How Can You Mend A Broken Heart',
#   'release_date': '2020-12-11',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/4vAhQeeWkSjVn0p5GAaLBx'},
#  {'album_id': 14,
#   'name': 'Twelve Carat Toothache',
#   'release_date': '2022-06-03',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3HHNR44YbP7XogMVwzbodx'},
#  {'album_id': 12,
#   'name': 'Familia',
#   'release_date': '2022-04-07',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4urxMitPAkjyey14LeuWSX'},
#  {'album_id': 1,
#   'name': 'Shakira: Bzrp Music Sessions, Vol. 53',
#   'release_date': '2023-01-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1gi2iwr1l8IUyHYHxi01pg'},
#  {'album_id': 13,
#   'name': 'Dreaming Out Loud',
#   'release_date': '2007-01-01',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2KSpGeDoNjqCKg6HL8LAyI'},
#  {'album_id': 16,
#   'name': '...Baby One More Time (Digital Deluxe Version)',
#   'release_date': '1999-01-12',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#  {'album_id': 12,
#   'name': 'Oops!... I Did It Again',
#   'release_date': '2000-05-16',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#  {'album_id': 36,
#   'name': 'One Thing At A Time',
#   'release_date': '2023-03-03',
#   'total_tracks': 36,
#   'url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': 14,
#   'name': 'If I Know Me',
#   'release_date': '2018-04-27',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/1IR2nlwX6YVTXXeu2qzoWO'},
#  {'album_id': 15,
#   'name': 'The Game (Deluxe Remastered Version)',
#   'release_date': '1980-06-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6wPXUmYJ9mOWrKlLzZ5cCa'},
#  {'album_id': 18,
#   'name': 'Sheer Heart Attack (Deluxe Remastered Version)',
#   'release_date': '1974-11-08',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6RJyYMIrOtx3VnNIoq31kj'},
#  {'album_id': 16,
#   'name': 'News Of The World (Deluxe Remastered Version)',
#   'release_date': '1977-10-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/6Di4m5k1BtMJ0R44bWNutu'},
#  {'album_id': 15,
#   'name': 'The Works (Deluxe Remastered Version)',
#   'release_date': '1984-02-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7oHaj9jkWHByziQsqGAb8V'},
#  {'album_id': 16,
#   'name': 'folklore',
#   'release_date': '2020-07-24',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#  {'album_id': 18,
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': 1,
#   'name': 'Daylight',
#   'release_date': '2023-04-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6NcI39WPu4kY6Tul11nhSv'},
#  {'album_id': 1,
#   'name': 'Classy 101',
#   'release_date': '2023-03-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4jtQUtS4ABgER3DnGfKJCv'},
#  {'album_id': 1,
#   'name': 'Shut up My Moms Calling',
#   'release_date': '2020-02-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4qVzNqB4cskFInYfrC7P0S'},
#  {'album_id': 1,
#   'name': 'Those Eyes',
#   'release_date': '2019-05-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7rItmPh0tZpMKcFXBScaU8'},
#  {'album_id': 6,
#   'name': 'FACE',
#   'release_date': '2023-03-24',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4xc3Lc9yASZgEJGH7acWMB'},
#  {'album_id': 3,
#   'name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'},
#  {'album_id': 12,
#   'name': 'CHARLIE',
#   'release_date': '2022-10-06',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/5Jk4Eg7pxYhDrWJCVVzmMt'},
#  {'album_id': 4,
#   'name': 'Something in the Orange',
#   'release_date': '2022-04-22',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1CmTOKCeyz1aHH04OwvTPv'},
#  {'album_id': 12,
#   'name': 'French Exit',
#   'release_date': '2014-06-05',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/4Hai0uVzRbyTSaTPzxTY4e'},
#  {'album_id': 23,
#   'name': 'Trouble Deluxe Edition',
#   'release_date': '2005-01-01',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/77eKpEVxmSr1RhqMlirlTF'},
#  {'album_id': 11,
#   'name': 'Pineapple Sunrise',
#   'release_date': '2023-03-03',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/7gA8QSNSZvHUYC9feFpeLj'},
#  {'album_id': 3,
#   'name': 'The Beginning: Cupid',
#   'release_date': '2023-02-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
#  {'album_id': 11,
#   'name': 'El Comienzo',
#   'release_date': '2023-08-03',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/44ugNcdxZyGhNiW2WWil0b'},
#  {'album_id': 2,
#   'name': "Boy's a liar Pt. 2",
#   'release_date': '2023-02-03',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6cVfHBcp3AdpYY0bBglkLN'},
#  {'album_id': 15,
#   'name': 'Plastic Hearts',
#   'release_date': '2020-11-27',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/5BRhg6NSEZOj0BR6Iz56fR'},
#  {'album_id': 17,
#   'name': 'Resistencia',
#   'release_date': '2023-01-13',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5xefnzEqKIWnmTWYFzekGZ'},
#  {'album_id': 10,
#   'name': 'Weezer',
#   'release_date': '2001-05-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/2OBSz5Nlto0Q5CtYPzPY7c'},
#  {'album_id': 2,
#   'name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#  {'album_id': 1,
#   'name': 'Until I Found You (Em Beihold Version)',
#   'release_date': '2022-04-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7ARtQpvnPN2ucbmVHngLOs'},
#  {'album_id': 18,
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': 14,
#   'name': 'Honestly, Nevermind',
#   'release_date': '2022-06-17',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3cf4iSSKd8ffTncbtKljXw'},
#  {'album_id': 16,
#   'name': 'folklore',
#   'release_date': '2020-07-24',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#  {'album_id': 17,
#   'name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': 9,
#   'name': 'Petals to Thorns',
#   'release_date': '2023-05-26',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/3rrrTOHiXGzuW4FP7t0O1A'},
#  {'album_id': 18,
#   'name': 'OzuTochi',
#   'release_date': '2022-10-07',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1kjfMVBNhsDeRyAu9zbLfF'},
#  {'album_id': 14,
#   'name': 'Graduation',
#   'release_date': '2007-09-11',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4SZko61aMnmgvNhfhgTuD3'},
#  {'album_id': 15,
#   'name': 'reputation',
#   'release_date': '2017-11-10',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'},
#  {'album_id': 1,
#   'name': 'SNAP',
#   'release_date': '2022-03-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4fb1QzgTJpTk9TBjFzjmlR'},
#  {'album_id': 13,
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': 12,
#   'name': 'this is what ____ feels like (Vol. 1-4)',
#   'release_date': '2022-09-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/69AaAkdktFGnk9POmHENkT'},
#  {'album_id': 16,
#   'name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'album_id': 17,
#   'name': 'Blonde',
#   'release_date': '2016-08-20',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/3mH6qwIy9crq0I9YQbOuDf'},
#  {'album_id': 17,
#   'name': 'channel ORANGE',
#   'release_date': '2012-07-10',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/392p3shh2jkxUxY2VHvlH8'},
#  {'album_id': 13,
#   'name': '1989',
#   'release_date': '2014-10-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  {'album_id': 32,
#   'name': 'Mercury - Acts 1 & 2',
#   'release_date': '2022-07-01',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/6yiXkzHvC0OTmhfDQOEWtS'},
#  {'album_id': 10,
#   'name': 'Cigarettes After Sex',
#   'release_date': '2017-06-09',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/5bP82ZIls6rzhpf5Qu6AzC'},
#  {'album_id': 15,
#   'name': 'HEROES & VILLAINS',
#   'release_date': '2022-12-02',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#  {'album_id': 17,
#   'name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': 2,
#   'name': 'LALISA',
#   'release_date': '2021-09-10',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/66OYt73mqan1hWa78BhfPd'},
#  {'album_id': 10,
#   'name': 'Gemini Rights',
#   'release_date': '2022-07-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/3Ks0eeH0GWpY4AU20D5HPD'},
#  {'album_id': 1,
#   'name': 'Dark Red',
#   'release_date': '2017-02-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7vrsFZNVhrriKh0SZKJW41'},
#  {'album_id': 24,
#   'name': 'Born To Die – Paradise Edition (Special Version)',
#   'release_date': '2012-01-01',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/0Dt3FbpMQwjoT5KNAw0IXR'},
#  {'album_id': 1,
#   'name': 'Young And Beautiful',
#   'release_date': '2013-01-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1D92WOHWUI2AGQCCdplcXL'},
#  {'album_id': 24,
#   'name': 'Born To Die – Paradise Edition (Special Version)',
#   'release_date': '2012-01-01',
#   'total_tracks': 24,
#   'url': 'https://open.spotify.com/album/0Dt3FbpMQwjoT5KNAw0IXR'},
#  {'album_id': 42,
#   'name': 'Indigo (Extended)',
#   'release_date': '2019-10-04',
#   'total_tracks': 42,
#   'url': 'https://open.spotify.com/album/3okhA6w5uau6ZNhnVpwVww'},
#  {'album_id': 15,
#   'name': 'reputation',
#   'release_date': '2017-11-10',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/6DEjYFkNZh67HP7R9PSZvv'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)
print(len(artist_list))
# Out:
# 1126

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration =  row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name': song_name, 'duration_ms': song_duration, 'url': song_url, 
                   'popularity': song_popularity, 'song_added': song_added, 'album_id': album_id,
                   'artist_id':artist_id
                   }
    song_list.append(song_element)
print(len(song_list))
# Out:
# 772

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      772 non-null    int64
#  1   name          772 non-null    object
#  2   release_date  772 non-null    object
#  3   total_tracks  772 non-null    int64
#  4   url           772 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 30.3+ KB

# %%
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
album_df
# Out:
#      album_id                                               name release_date  \
# 0          14                                        After Hours   2020-03-20
# 1          16                                         ÷ (Deluxe)   2017-03-03
# 2          12            Divinely Uninspired To A Hellish Extent   2019-05-17
# 3          20                   Welcome To The Madhouse (Deluxe)   2021-07-16
# 4          13  Spider-Man: Into the Spider-Verse (Soundtrack ...   2018-12-14
# 5          18                               beerbongs & bentleys   2018-04-27
# 7          29                              F*CK LOVE 3: OVER YOU   2021-07-23
# 8          11                                             Evolve   2017-06-23
# 10          5                                         Collage EP   2016-11-04
# 15         17                                 Back from the Edge   2016-10-28
# 16          1                               lovely (with Khalid)   2018-04-19
# 23         25                                           Scorpion   2018-06-29
# 27         34                          A Star Is Born Soundtrack   2018-10-05
# 30         19                                   Purpose (Deluxe)   2015-11-13
# 38         15             Dream Your Life Away (Special Edition)   2014-09-09
# 58         24            Curtain Call: The Hits (Deluxe Edition)   2005-12-06
# 59         10                                 In The Lonely Hour   2014-05-26
# 61          9                               Peace Is The Mission   2015-06-01
# 68          4                                              Faded   2015-12-04
# 84          8                                                 BE   2020-11-20
# 86         40  (What's The Story) Morning Glory? (Deluxe Edit...   1995-10-02
# 116         7                               FRIENDS KEEP SECRETS   2018-12-07
# 152        22                                  Delirium (Deluxe)   2015-11-06
# 180        30                   Thriller 25 Super Deluxe Edition   2008-02-08
# 181        23                           Nothing but the Beat 2.0   2011-08-24
# 188         6                              All Your Fault: Pt. 2   2017-08-11
# 264        58                             Rumours (Super Deluxe)   1977-02-04
# 310        21                                      High Off Life   2020-05-15
# 314        35                                              Proof   2022-06-10
# 318         3                                     LAST CHRISTMAS   1984-11-29
# 355        59    Songs From The Big Chair (Super Deluxe Edition)   1985-02-25
# 418         2                                    I'm Good (Blue)   2022-08-26
# 445        26                    Small Town Boy (Track By Track)   2020-11-12
# 638        49                     The Joshua Tree (Super Deluxe)   1987-03-03
# 646        32                                             Indigo   2019-06-28
# 659        39                Tango In the Night (Deluxe Edition)   1987-04-13
# 667        47                    Once Upon A Time (Super Deluxe)         1985
# 690        48                      The Very Best of Bonnie Tyler   2009-03-26
# 718        36                                One Thing At A Time   2023-03-03
# 770        42                                  Indigo (Extended)   2019-10-04
#
#      total_tracks                                                url
# 0              14  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1              16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2              12  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3              20  https://open.spotify.com/album/1AZjTOqvw2ZogWZ...
# 4              13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 5              18  https://open.spotify.com/album/6trNtQUgC8cgbWc...
# 7              29  https://open.spotify.com/album/4bZJWQhHKJckFLJ...
# 8              11  https://open.spotify.com/album/51s30K7a36ORx6A...
# 10              5  https://open.spotify.com/album/22rp3PnM3q2mtTI...
# 15             17  https://open.spotify.com/album/7oiJYvEJHsmYtrg...
# 16              1  https://open.spotify.com/album/2sBB17RXTamvj7N...
# 23             25  https://open.spotify.com/album/1ATL5GLyefJaxhQ...
# 27             34  https://open.spotify.com/album/4sLtOBOzn4s3GDU...
# 30             19  https://open.spotify.com/album/6Fr2rQkZ383FcMq...
# 38             15  https://open.spotify.com/album/5S9b8euumqMhQbM...
# 58             24  https://open.spotify.com/album/5qENHeCSlwWpEzb...
# 59             10  https://open.spotify.com/album/08jWgM4vSkTose4...
# 61              9  https://open.spotify.com/album/4DOcG4A40Wf3q2v...
# 68              4  https://open.spotify.com/album/5HMjpBO0v78ayq5...
# 84              8  https://open.spotify.com/album/6nYfHQnvkvOTNHn...
# 86             40  https://open.spotify.com/album/6ozp33PI3p9Addd...
# 116             7  https://open.spotify.com/album/7dQ734EW0iLvQfF...
# 152            22  https://open.spotify.com/album/20Ol6zZ0nLlc5EG...
# 180            30  https://open.spotify.com/album/1C2h7mLntPSeVYc...
# 181            23  https://open.spotify.com/album/5aprcHwM1KJhaY9...
# 188             6  https://open.spotify.com/album/6t5D6LEgHxqUVOx...
# 264            58  https://open.spotify.com/album/0BwWUstDMUbgq2N...
# 310            21  https://open.spotify.com/album/4bNPOFOzxGhF5jh...
# 314            35  https://open.spotify.com/album/6al2VdKbb6FIz9d...
# 318             3  https://open.spotify.com/album/6egzU9NKfora01q...
# 355            59  https://open.spotify.com/album/3myPwaMYjdwhtq0...
# 418             2  https://open.spotify.com/album/7M842DMhYVALrXs...
# 445            26  https://open.spotify.com/album/4fEgAL4ge9hHhxV...
# 638            49  https://open.spotify.com/album/5y6wlw1LnqFnQFr...
# 646            32  https://open.spotify.com/album/1BfLzaTFI5qKsAA...
# 659            39  https://open.spotify.com/album/4AsXQ17Arq1cUVo...
# 667            47  https://open.spotify.com/album/4YimfceN1R0nOS9...
# 690            48  https://open.spotify.com/album/0VJI3wpebzRyVHq...
# 718            36  https://open.spotify.com/album/6i7mF7whyRJuLJ4...
# 770            42  https://open.spotify.com/album/3okhA6w5uau6ZNh...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df = song_df.drop_duplicates(subset = ['song_id'])

# %%
song_df.head(10)
# Out:
#                   song_id                                      song_name  \
# 0  0VjIjW4GlUZAMYd2vXMi3b                                Blinding Lights
# 1  7qiZfU4dY1lWllzX7mPBI3                                   Shape of You
# 2  7qEHsqek33rTcFNT9PFqLf                              Someone You Loved
# 3  2N8m6CYs74qQO4mjVcXO30                                   Dance Monkey
# 4  3KkXRkHbMCARz0aVfEt68P  Sunflower - Spider-Man: Into the Spider-Verse
# 5  0e7ipj03S05BNilyu5bRzt                     rockstar (feat. 21 Savage)
# 6  12VWzyPDBCc8fqeWCAfNwR                                      One Dance
# 7  5PjdY0CKGZdEuoNab3yDmX                      STAY (with Justin Bieber)
# 8  1NtIMM4N0cFa1dNzN15chl                                       Believer
# 9  7MXVkk9YMctZqd1Srtv4MB                                        Starboy
#
#    duration_ms                                                url  popularity  \
# 0       200040  https://open.spotify.com/track/0VjIjW4GlUZAMYd...          90
# 1       233712  https://open.spotify.com/track/7qiZfU4dY1lWllz...          88
# 2       182160  https://open.spotify.com/track/7qEHsqek33rTcFN...          89
# 3       209438  https://open.spotify.com/track/2N8m6CYs74qQO4m...          76
# 4       158040  https://open.spotify.com/track/3KkXRkHbMCARz0a...          86
# 5       218146  https://open.spotify.com/track/0e7ipj03S05BNil...          85
# 6       173986  https://open.spotify.com/track/12VWzyPDBCc8fqe...           1
# 7       141805  https://open.spotify.com/track/5PjdY0CKGZdEuoN...          25
# 8       204346  https://open.spotify.com/track/1NtIMM4N0cFa1dN...           0
# 9       230453  https://open.spotify.com/track/7MXVkk9YMctZqd1...          92
#
#              song_added                album_id               artist_id
# 0  2020-03-20T04:54:59Z  4yP0hdKOZPNshxUOjY0cZj  1Xyo4u8uXC1ZmMpatF05PJ
# 1  2017-06-09T00:39:52Z  3T4tUhGYeRNVUGevb0wThu  6eUKZXaKkcviH0Ku9w2n3V
# 2  2019-08-31T17:45:01Z  5658aM19fA3JVwTK6eQX70  4GNC7GD6oZMSxPGyXy4MNB
# 3  2022-05-13T18:52:31Z  1AZjTOqvw2ZogWZxnDlhEN  2NjfBq1NflQcKSeiDooVjY
# 4  2019-08-31T17:18:20Z  35s58BRTGAEWztPo9WqCIs  0LyfQWJT6nXafLPZqxe9Of
# 5  2020-03-28T02:36:06Z  6trNtQUgC8cgbWcqoMYkOR  246dkjvS1zLTtiykXe5h60
# 6  2016-06-27T04:39:48Z  0G1ffjfFuTUTVjDrVdLimH  3TVXtAsR1Inumwj472S9r4
# 7  2021-08-08T01:20:27Z  4bZJWQhHKJckFLJuYdvyX2  2tIP7SsRs7vjIcLrU85W8J
# 8  2018-01-04T16:46:17Z  51s30K7a36ORx6AAaPBRRY  53XhwfbYqKCa1cC15pYq2q
# 9  2017-06-09T00:44:54Z  2ODvWsOgouMbaA5xf0RkJe  1Xyo4u8uXC1ZmMpatF05PJ

# %%
album_df.head(10)
# Out:
#     album_id                                               name release_date  \
# 0         14                                        After Hours   2020-03-20
# 1         16                                         ÷ (Deluxe)   2017-03-03
# 2         12            Divinely Uninspired To A Hellish Extent   2019-05-17
# 3         20                   Welcome To The Madhouse (Deluxe)   2021-07-16
# 4         13  Spider-Man: Into the Spider-Verse (Soundtrack ...   2018-12-14
# 5         18                               beerbongs & bentleys   2018-04-27
# 7         29                              F*CK LOVE 3: OVER YOU   2021-07-23
# 8         11                                             Evolve   2017-06-23
# 10         5                                         Collage EP   2016-11-04
# 15        17                                 Back from the Edge   2016-10-28
#
#     total_tracks                                                url
# 0             14  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1             16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2             12  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3             20  https://open.spotify.com/album/1AZjTOqvw2ZogWZ...
# 4             13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 5             18  https://open.spotify.com/album/6trNtQUgC8cgbWc...
# 7             29  https://open.spotify.com/album/4bZJWQhHKJckFLJ...
# 8             11  https://open.spotify.com/album/51s30K7a36ORx6A...
# 10             5  https://open.spotify.com/album/22rp3PnM3q2mtTI...
# 15            17  https://open.spotify.com/album/7oiJYvEJHsmYtrg...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.head(10)
# Out:
#     album_id                                               name release_date  \
# 0         14                                        After Hours   2020-03-20
# 1         16                                         ÷ (Deluxe)   2017-03-03
# 2         12            Divinely Uninspired To A Hellish Extent   2019-05-17
# 3         20                   Welcome To The Madhouse (Deluxe)   2021-07-16
# 4         13  Spider-Man: Into the Spider-Verse (Soundtrack ...   2018-12-14
# 5         18                               beerbongs & bentleys   2018-04-27
# 7         29                              F*CK LOVE 3: OVER YOU   2021-07-23
# 8         11                                             Evolve   2017-06-23
# 10         5                                         Collage EP   2016-11-04
# 15        17                                 Back from the Edge   2016-10-28
#
#     total_tracks                                                url
# 0             14  https://open.spotify.com/album/4yP0hdKOZPNshxU...
# 1             16  https://open.spotify.com/album/3T4tUhGYeRNVUGe...
# 2             12  https://open.spotify.com/album/5658aM19fA3JVwT...
# 3             20  https://open.spotify.com/album/1AZjTOqvw2ZogWZ...
# 4             13  https://open.spotify.com/album/35s58BRTGAEWztP...
# 5             18  https://open.spotify.com/album/6trNtQUgC8cgbWc...
# 7             29  https://open.spotify.com/album/4bZJWQhHKJckFLJ...
# 8             11  https://open.spotify.com/album/51s30K7a36ORx6A...
# 10             5  https://open.spotify.com/album/22rp3PnM3q2mtTI...
# 15            17  https://open.spotify.com/album/7oiJYvEJHsmYtrg...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 772 entries, 0 to 771
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      772 non-null    object
#  1   song_name    772 non-null    object
#  2   duration_ms  772 non-null    int64
#  3   url          772 non-null    object
#  4   popularity   772 non-null    int64
#  5   song_added   772 non-null    datetime64[ns, UTC]
#  6   album_id     772 non-null    object
#  7   artist_id    772 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 54.3+ KB
